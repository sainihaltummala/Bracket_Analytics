# %%
# %matplotlib inline
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
fileRead=pd.DataFrame()
fileRead=pd.read_csv('TeamMonthTotal.csv')
print(fileRead.head(20))
# Out:
#     Index                 Team   MP  FG  FGA    FG%  2P  2PA    2P%  3P  ...   \
# 0      15            schreiner  200  23   53  0.434  15   32  0.469   8  ...
# 1      12    abilene-christian  200  27   64  0.422  18   42  0.429   9  ...
# 2      18            mcpherson  200  27   63  0.429  15   29  0.517  12  ...
# 3      19            air-force  200  28   50  0.560  20   28  0.714   8  ...
# 4     121     coastal-carolina  200  17   62  0.274   8   39  0.205   9  ...
# 5      14              alabama  200  21   48  0.438  11   22  0.500  10  ...
# 6      13  arkansas-pine-bluff  200  22   62  0.355  12   36  0.333  10  ...
# 7     141   alabama-birmingham  200  25   53  0.472  22   37  0.595   3  ...
# 8      16       portland-state  200  26   67  0.388  20   40  0.500   6  ...
# 9     142        arizona-state  200  33   67  0.493  24   39  0.615   9  ...
# 10    132                 ipfw  200  25   69  0.362  16   41  0.390   9  ...
# 11    131             arkansas  200  35   66  0.530  29   50  0.580   6  ...
# 12    143        north-florida  200  22   57  0.386  16   37  0.432   6  ...
# 13    133               auburn  200  25   60  0.417  12   28  0.429  13  ...
# 14    122         oral-roberts  200  24   58  0.414  21   45  0.467   3  ...
# 15   1211               baylor  200  24   54  0.444  14   28  0.500  10  ...
# 16    144              cornell  200  22   63  0.349  18   34  0.529   4  ...
# 17   1411           binghamton  200  23   58  0.397  16   39  0.410   7  ...
# 18    123       nicholls-state  200  30   61  0.492  25   43  0.581   5  ...
# 19    134       boston-college  200  26   52  0.500  17   34  0.500   9  ...
#
#     Opp DRB  Opp TRB  Opp AST  Opp STL  Opp BLK  Opp TOV  Opp PF  Opp PTS  \
# 0        26       41       13        8        5       11      17       73
# 1        22       27       18        6        2       14      14       59
# 2        26       30       20        4        1        6      17       88
# 3        18       29       13        2        0       10      27       71
# 4        29       36       13        8        8       11      19       70
# 5        21       31        7        2        2       13      22       53
# 6        30       41       19       10        9       15      19       86
# 7        16       27       10        7        1       17      28       66
# 8        29       40       11        7        3       16      15       88
# 9        21       29       14        5        1       14      20       70
# 10       29       37       20        9        9       13      29       92
# 11       21       40       12        5        2       12      24       83
# 12       24       33       17       11        6       17      20       83
# 13       25       37       10        2        2       28      30       66
# 14       26       35       18        9        5       11      18       76
# 15       22       30       13        3        0       14      19       61
# 16       29       33       10        5        4       10      20       68
# 17       34       43        9        2        4       12      19       62
# 18       25       30       15        4        4       16      23       73
# 19       23       30       16        8        4        9      18       79
#
#         gameid  Win?
# 0    111120161     0
# 1    111120161     1
# 2    111120162     0
# 3    111120162     1
# 4    111120163     0
# 5    111120163     1
# 6    111120164     0
# 7    111120164     1
# 8    111120165     0
# 9    111120165     1
# 10   111120166     0
# 11   111120166     1
# 12   111120167     0
# 13   111120167     1
# 14   111120168     0
# 15   111120168     1
# 16   111120169     0
# 17   111120169     1
# 18  1111201610     1
# 19  1111201610     0
#
# [20 rows x 47 columns]

# %%
nf = 15
pca = PCA(n_components=nf)
# X is the matrix transposed (n samples on the rows, m features on the columns)
pca.fit(fileRead)

X_new = pca.transform(fileRead)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-5f9fc17d8472> in <module>()
#       2 pca = PCA(n_components=nf)
#       3 # X is the matrix transposed (n samples on the rows, m features on the columns)
# ----> 4 pca.fit(fileRead)
#       5
#       6 X_new = pca.transform(fileRead)
#
# ~\Anaconda3\lib\site-packages\sklearn\decomposition\pca.py in fit(self, X, y)
#     327             Returns the instance itself.
#     328         """
# --> 329         self._fit(X)
#     330         return self
#     331
#
# ~\Anaconda3\lib\site-packages\sklearn\decomposition\pca.py in _fit(self, X)
#     368
#     369         X = check_array(X, dtype=[np.float64, np.float32], ensure_2d=True,
# --> 370                         copy=self.copy)
#     371
#     372         # Handle n_components==None
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     431                                       force_all_finite)
#     432     else:
# --> 433         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     434
#     435         if ensure_2d:
#
# ValueError: could not convert string to float: 'north-carolina'

# %%
fileRead.dropna
# Out:
# <bound method DataFrame.dropna of         Index                       Team   MP  FG  FGA    FG%  2P  2PA    2P%  \
# 0          15                  schreiner  200  23   53  0.434  15   32  0.469
# 1          12          abilene-christian  200  27   64  0.422  18   42  0.429
# 2          18                  mcpherson  200  27   63  0.429  15   29  0.517
# 3          19                  air-force  200  28   50  0.560  20   28  0.714
# 4         121           coastal-carolina  200  17   62  0.274   8   39  0.205
# 5          14                    alabama  200  21   48  0.438  11   22  0.500
# 6          13        arkansas-pine-bluff  200  22   62  0.355  12   36  0.333
# 7         141         alabama-birmingham  200  25   53  0.472  22   37  0.595
# 8          16             portland-state  200  26   67  0.388  20   40  0.500
# 9         142              arizona-state  200  33   67  0.493  24   39  0.615
# 10        132                       ipfw  200  25   69  0.362  16   41  0.390
# 11        131                   arkansas  200  35   66  0.530  29   50  0.580
# 12        143              north-florida  200  22   57  0.386  16   37  0.432
# 13        133                     auburn  200  25   60  0.417  12   28  0.429
# 14        122               oral-roberts  200  24   58  0.414  21   45  0.467
# 15       1211                     baylor  200  24   54  0.444  14   28  0.500
# 16        144                    cornell  200  22   63  0.349  18   34  0.529
# 17       1411                 binghamton  200  23   58  0.397  16   39  0.410
# 18        123             nicholls-state  200  30   61  0.492  25   43  0.581
# 19        134             boston-college  200  26   52  0.500  17   34  0.500
# 20         17       illinois-springfield  200  20   58  0.345  17   40  0.425
# 21        151                    bradley  200  26   55  0.473  17   35  0.486
# 22        145                  manhattan  200  22   62  0.355  14   40  0.350
# 23       1412                   bucknell  200  25   52  0.481  18   34  0.529
# 24        181                   cal-tech  200  12   55  0.218   8   33  0.242
# 25        146        cal-state-fullerton  200  28   52  0.538  21   34  0.618
# 26        147              pomona-pitzer  200  23   72  0.319  15   48  0.313
# 27        171       cal-state-northridge  200  34   64  0.531  26   47  0.553
# 28        148         south-dakota-state  200  16   56  0.286   8   26  0.308
# 29        161                 california  200  30   64  0.469  18   32  0.563
# ...       ...                        ...  ...  ..  ...    ...  ..  ...    ...
# 11902   13267                    liberty  200  23   51  0.451  14   30  0.467
# 11903   12307  maryland-baltimore-county  200  26   51  0.510  15   22  0.682
# 11904   12308                   kentucky  200  27   65  0.415  20   46  0.435
# 11905   13268             north-carolina  200  27   58  0.466  24   43  0.558
# 11906    1599                       ipfw  200  19   48  0.396   8   16  0.500
# 11907   15116    texas-am-corpus-christi  200  29   64  0.453  26   50  0.520
# 11908   13269                    wyoming  200  28   63  0.444  15   29  0.517
# 11909   11196           coastal-carolina  200  34   72  0.472  26   51  0.510

# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-94-4c7e1b60098b> in <module>()
# ----> 1 new_team_1 = new_team.drop('gameid','Win?').dropna()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, level, inplace, errors)
#    2149         """
#    2150         inplace = validate_bool_kwarg(inplace, 'inplace')
# -> 2151         axis = self._get_axis_number(axis)
#    2152         axis_name = self._get_axis_name(axis)
#    2153         axis, axis_ = self._get_axis(axis), axis
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(self, axis)
#     351                 pass
#     352         raise ValueError('No axis named {0} for object type {1}'
# --> 353                          .format(axis, type(self)))
#     354
#     355     def _get_axis_name(self, axis):
#
# ValueError: No axis named Win? for object type <class 'pandas.core.frame.DataFrame'>

# %%
new_team_1
# Out:
#         Index   MP  FG  FGA    FG%  2P  2PA    2P%  3P  3PA  ...   Opp ORB  \
# 0          15  200  23   53  0.434  15   32  0.469   8   21  ...        15
# 1          12  200  27   64  0.422  18   42  0.429   9   22  ...         5
# 2          18  200  27   63  0.429  15   29  0.517  12   34  ...         4
# 3          19  200  28   50  0.560  20   28  0.714   8   22  ...        11
# 4         121  200  17   62  0.274   8   39  0.205   9   23  ...         7
# 5          14  200  21   48  0.438  11   22  0.500  10   26  ...        10
# 6          13  200  22   62  0.355  12   36  0.333  10   26  ...        11
# 7         141  200  25   53  0.472  22   37  0.595   3   16  ...        11
# 8          16  200  26   67  0.388  20   40  0.500   6   27  ...        11
# 9         142  200  33   67  0.493  24   39  0.615   9   28  ...         8
# 10        132  200  25   69  0.362  16   41  0.390   9   28  ...         8
# 11        131  200  35   66  0.530  29   50  0.580   6   16  ...        19
# 12        143  200  22   57  0.386  16   37  0.432   6   20  ...         9
# 13        133  200  25   60  0.417  12   28  0.429  13   32  ...        12
# 14        122  200  24   58  0.414  21   45  0.467   3   13  ...         9
# 15       1211  200  24   54  0.444  14   28  0.500  10   26  ...         8
# 16        144  200  22   63  0.349  18   34  0.529   4   29  ...         4
# 17       1411  200  23   58  0.397  16   39  0.410   7   19  ...         9
# 18        123  200  30   61  0.492  25   43  0.581   5   18  ...         5
# 19        134  200  26   52  0.500  17   34  0.500   9   18  ...         7
# 20         17  200  20   58  0.345  17   40  0.425   3   18  ...         6
# 21        151  200  26   55  0.473  17   35  0.486   9   20  ...         9
# 22        145  200  22   62  0.355  14   40  0.350   8   22  ...         7
# 23       1412  200  25   52  0.481  18   34  0.529   7   18  ...        18
# 24        181  200  12   55  0.218   8   33  0.242   4   22  ...         7
# 25        146  200  28   52  0.538  21   34  0.618   7   18  ...         4
# 26        147  200  23   72  0.319  15   48  0.313   8   24  ...         9
# 27        171  200  34   64  0.531  26   47  0.553   8   17  ...         8
# 28        148  200  16   56  0.286   8   26  0.308   8   30  ...        11
# 29        161  200  30   64  0.469  18   32  0.563  12   32  ...         1
# ...       ...  ...  ..  ...    ...  ..  ...    ...  ..  ...  ...       ...
# 11902   13267  200  23   51  0.451  14   30  0.467   9   21  ...         3
# 11903   12307  200  26   51  0.510  15   22  0.682  11   29  ...         1
# 11904   12308  200  27   65  0.415  20   46  0.435   7   19  ...         9
# 11905   13268  200  27   58  0.466  24   43  0.558   3   15  ...        10
# ...        ...      ...      ...      ...      ...      ...     ...      ...
# 11902       27       30       16        4        1       11      12       80
# 11903       19       20       12        5        0        9      18       68
# 11904       29       38       17        7        9       15      18       75
# 11905       23       33       16        7        2        9      19       73
# 11906       24       37       16       15        3       13      18       78
# 11907       23       28       14        6        3       18      20       62
# 11908       25       38       14       10        3       11      17       91
# 11909       23       29       13        6        5       15      23       81
# 11910       24       29        5        8        7        7      17       53
# 11911       27       40       20        2        5       12      15       68
# 11912       28       37       16        6        8        7      13       76
# 11913       25       37       13        5        4       15      21       61
# 11914       30       31        8        6        4       21      18       61
# 11915       24       29       16       14        1       13      23       79
# 11916       29       33       21       10        3       13      14       77
# 11917       18       22        9        6        1       14      17       51
# 11918       33       39       14        3        6       13      15       81
# 11919       23       33        9        9        2        9      24       57
# 11920       25       37       17       13        3        8      16       88
# 11921       17       26       12        4        5       17      17       56
# 11922       21       29       15       11        5       13      15       61
# 11923       23       28       13        8        3       13      17       62
# 11924       27       38       14        4        2        7      15       83
# 11925       22       30        4        3        2       10      22       59
# 11926       31       37       15        3        8       12      21       77
# 11927       23       35       12        7        6        5      14       73
# 11928       26       42       16        7        3       11      22       77
# 11929       31       42        7        5        7       16      20       76
# 11930       31       46       15        7        8        4      22       71
# 11931       35       44       11        2        5       14      22       65
#
#        Win?
# 0         0
# 1         1
# 2         0
# 3         1
# 4         0
# 5         1
# 6         0
# 7         1
# 8         0
# 9         1
# 10        0
# 11        1
# 12        0
# 13        1
# 14        0
# 15        1
# 16        0
# 17        1
# 18        1
# 19        0
# 20        0
# 21        1
# 22        0
# 23        1
# 24        0
# 25        1
# 26        0
# 27        1
# 28        0
# 29        1
# ...     ...
# 11902     0
# 11903     1
# 11904     0
# 11905     1
# 11906     0
# 11907     1
# 11908     0
# 11909     1
# 11910     1
# 11911     0
# 11912     0
# 11913     1
# 11914     1
# 11915     0
# 11916     0
# 11917     1
# 11918     0
# 11919     1
# 11920     0
# 11921     1
# 11922     1
# 11923     0
# 11924     0
# 11925     1
# 11926     0
# 11927     1
# 11928     0
# 11929     1
# 11930     0
# 11931     1
#
# [11929 rows x 45 columns]

# %%
new_team.shape
# Out:
# (11929, 46)

# %%
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-c9a906f0be96> in <module>()
# ----> 1 new_team_transposed=pd.DataFrame.transpose(1)
#       2 df=new_team
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in transpose(self, *args, **kwargs)
#    1757         """Transpose index and columns"""
#    1758         nv.validate_transpose(args, dict())
# -> 1759         return super(DataFrame, self).transpose(1, 0, **kwargs)
#    1760
#    1761     T = property(transpose)
#
# TypeError: super(type, obj): obj must be an instance or subtype of type

# %%
nf = 1
pca = PCA(n_components=nf)
# X is the matrix transposed (n samples on the rows, m features on the columns)
pca.fit(new_team)

X_new = pca.transform(new_team)

# %%
 print(pca.explained_variance_ratio_) 
var_ration = pca.explained_variance_ratio_
plt.plot(var_ration)
# Out:
# [  1.00000000e+00   3.02320574e-10   1.20488195e-16   9.15817226e-17
#    4.99059667e-17   4.04432262e-17   3.89873897e-17   2.97272046e-17
#    2.53919574e-17   1.82821064e-17   1.69279254e-17   1.35112658e-17]

# %%
pca_components = pd.DataFrame()
pca_components['features'] = new_team.columns
pca_components['pca_contrib'] = pca.components_[0]
pca_components.sort_values('pca_contrib',ascending=False)
# Out:
#    features   pca_contrib
# 44   gameid  1.000000e+00
# 21       PF  1.507035e-10
# 42   Opp PF  1.506974e-10
# 22      PTS  1.414911e-10
# 43  Opp PTS  1.411054e-10
# 20      TOV  1.391967e-10
# 41  Opp TOV  1.391836e-10
# 3       FGA  1.166888e-10
# 24  Opp FGA  1.165927e-10
# 33  Opp FTA  1.135155e-10
# 12      FTA  1.133443e-10
# 37  Opp TRB  1.082190e-10
# 16      TRB  1.081989e-10
# 9       3PA  9.760417e-11
# 30  Opp 3PA  9.706204e-11
# 17      AST  7.744013e-11
# 38  Opp AST  7.718265e-11
# 35  Opp ORB  5.818314e-11
# 14      ORB  5.810633e-11
# 15      DRB  5.009261e-11
# 36  Opp DRB  5.003588e-11
# 39  Opp STL  4.315187e-11
# 18      STL  4.307767e-11
# 8        3P  4.147626e-11
# 29   Opp 3P  4.120826e-11
# 2        FG  3.450198e-11
# 23   Opp FG  3.437282e-11
# 32   Opp FT  3.115146e-11
# 11       FT  3.101086e-11
# 27  Opp 2PA  1.953070e-11
# 6       2PA  1.908464e-11
# 19      BLK  8.003695e-12
# 40  Opp BLK  7.909405e-12
# 10      3P%  1.187820e-13
# 31  Opp 3P%  1.151131e-13
# 45     Win?  5.672411e-15
# 4       FG% -3.825504e-13
# 25  Opp FG% -3.840703e-13
# 7       2P% -6.648538e-13
# 28  Opp 2P% -6.660767e-13
# 34  Opp FT% -2.091126e-12
# 13      FT% -2.106842e-12
# 26   Opp 2P -6.835445e-12
# 5        2P -6.974275e-12
# 1        MP -2.761682e-11
# 0     Index -8.076636e-07

# %%
pca_components.plot('pca_contrib',figsize=(10,6))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-504fe28ee50e> in <module>()
# ----> 1 pca_components.plot('pca_contrib',figsize=(10,6))
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2625                           fontsize=fontsize, colormap=colormap, table=table,
#    2626                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2627                           sort_columns=sort_columns, **kwds)
#    2628     __call__.__doc__ = plot_frame.__doc__
#    2629
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1867                  yerr=yerr, xerr=xerr,
#    1868                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1869                  **kwds)
#    1870
#    1871
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1692         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1693
# -> 1694     plot_obj.generate()
#    1695     plot_obj.draw()
#    1696     return plot_obj.result
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in generate(self)
#     241     def generate(self):
#     242         self._args_adjust()
# --> 243         self._compute_plot_data()
#     244         self._setup_subplots()
#     245         self._make_plot()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _compute_plot_data(self)
#     350         if is_empty:
#     351             raise TypeError('Empty {0!r}: no numeric data to '
# --> 352                             'plot'.format(numeric_data.__class__.__name__))
#     353
#     354         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot

# %%
print(pca.explained_variance_)
# Out:
# [  2.78527331e+18]

# %%
print(component)

# %%
pca_components
# Out:
#    features
# 0     Index
# 1        MP
# 2        FG
# 3       FGA
# 4       FG%
# 5        2P
# 6       2PA
# 7       2P%
# 8        3P
# 9       3PA
# 10      3P%
# 11       FT
# 12      FTA
# 13      FT%
# 14      ORB
# 15      DRB
# 16      TRB
# 17      AST
# 18      STL
# 19      BLK
# 20      TOV
# 21       PF
# 22      PTS
# 23   Opp FG
# 24  Opp FGA
# 25  Opp FG%
# 26   Opp 2P
# 27  Opp 2PA
# 28  Opp 2P%
# 29   Opp 3P
# 30  Opp 3PA
# 31  Opp 3P%
# 32   Opp FT
# 33  Opp FTA
# 34  Opp FT%
# 35  Opp ORB
# 36  Opp DRB
# 37  Opp TRB
# 38  Opp AST
# 39  Opp STL
# 40  Opp BLK
# 41  Opp TOV
# 42   Opp PF
# 43  Opp PTS
# 44   gameid
# 45     Win?

# %%
print(fileRead.head(20))
# Out:
#     Index                 Team   MP  FG  FGA    FG%  2P  2PA    2P%  3P  ...   \
# 0      15            schreiner  200  23   53  0.434  15   32  0.469   8  ...
# 1      12    abilene-christian  200  27   64  0.422  18   42  0.429   9  ...
# 2      18            mcpherson  200  27   63  0.429  15   29  0.517  12  ...
# 3      19            air-force  200  28   50  0.560  20   28  0.714   8  ...
# 4     121     coastal-carolina  200  17   62  0.274   8   39  0.205   9  ...
# 5      14              alabama  200  21   48  0.438  11   22  0.500  10  ...
# 6      13  arkansas-pine-bluff  200  22   62  0.355  12   36  0.333  10  ...
# 7     141   alabama-birmingham  200  25   53  0.472  22   37  0.595   3  ...
# 8      16       portland-state  200  26   67  0.388  20   40  0.500   6  ...
# 9     142        arizona-state  200  33   67  0.493  24   39  0.615   9  ...
# 10    132                 ipfw  200  25   69  0.362  16   41  0.390   9  ...
# 11    131             arkansas  200  35   66  0.530  29   50  0.580   6  ...
# 12    143        north-florida  200  22   57  0.386  16   37  0.432   6  ...
# 13    133               auburn  200  25   60  0.417  12   28  0.429  13  ...
# 14    122         oral-roberts  200  24   58  0.414  21   45  0.467   3  ...
# 15   1211               baylor  200  24   54  0.444  14   28  0.500  10  ...
# 16    144              cornell  200  22   63  0.349  18   34  0.529   4  ...
# 17   1411           binghamton  200  23   58  0.397  16   39  0.410   7  ...
# 18    123       nicholls-state  200  30   61  0.492  25   43  0.581   5  ...
# 19    134       boston-college  200  26   52  0.500  17   34  0.500   9  ...
#
#     Opp DRB  Opp TRB  Opp AST  Opp STL  Opp BLK  Opp TOV  Opp PF  Opp PTS  \
# 0        26       41       13        8        5       11      17       73
# 1        22       27       18        6        2       14      14       59
# 2        26       30       20        4        1        6      17       88
# 3        18       29       13        2        0       10      27       71
# 4        29       36       13        8        8       11      19       70
# 5        21       31        7        2        2       13      22       53
# 6        30       41       19       10        9       15      19       86
# 7        16       27       10        7        1       17      28       66
# 8        29       40       11        7        3       16      15       88
# 9        21       29       14        5        1       14      20       70
# 10       29       37       20        9        9       13      29       92
# 11       21       40       12        5        2       12      24       83
# 12       24       33       17       11        6       17      20       83
# 13       25       37       10        2        2       28      30       66
# 14       26       35       18        9        5       11      18       76
# 15       22       30       13        3        0       14      19       61
# 16       29       33       10        5        4       10      20       68
# 17       34       43        9        2        4       12      19       62
# 18       25       30       15        4        4       16      23       73
# 19       23       30       16        8        4        9      18       79
#
#         gameid  Win?
# 0    111120161     0
# 1    111120161     1
# 2    111120162     0
# 3    111120162     1
# 4    111120163     0
# 5    111120163     1
# 6    111120164     0
# 7    111120164     1
# 8    111120165     0
# 9    111120165     1
# 10   111120166     0
# 11   111120166     1
# 12   111120167     0
# 13   111120167     1
# 14   111120168     0
# 15   111120168     1
# 16   111120169     0
# 17   111120169     1
# 18  1111201610     1
# 19  1111201610     0
#
# [20 rows x 47 columns]

# %%
import numpy as np
from sklearn.decomposition import PCA
X = np.array([[-1, -1], [-2, -1], [-3, -2], [1, 1], [2, 1], [3, 2]])
pca = PCA(n_components=2)
pca.fit(X)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)
